# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Processed.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#     Source  Severity           Start_Time                     Street
# 0  Source2         3  2016-02-07 23:46:00                     I-70 E  \
# 1  Source2         2  2016-02-08 00:07:59                   Brice Rd
# 2  Source2         2  2016-02-08 00:49:27             State Route 32
# 3  Source2         3  2016-02-08 01:23:34                     I-75 S
# 4  Source2         2  2016-02-08 01:39:07  Miamisburg Centerville Rd
#
#            City      County State  Zipcode Airport_Code  Temperature(F)  ...
# 0        Dayton  Montgomery    OH    45424         KFFO            36.9  ...  \
# 1  Reynoldsburg    Franklin    OH    43068         KCMH            37.9  ...
# 2  Williamsburg    Clermont    OH    45176         KI69            36.0  ...
# 3        Dayton  Montgomery    OH    45417         KDAY            35.1  ...
# 4        Dayton  Montgomery    OH    45459         KMGY            36.0  ...
#
#    No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming
# ...

# %%
severe_accidents = df[df['Severity'] == 4]

# Count the occurrences of each unique 'County' value
severe_count_by_county = severe_accidents['County'].value_counts()

# Find the county with the most severe accidents
most_severe_county = severe_count_by_county.idxmax()
most_severe_accidents = severe_count_by_county.max()

# %%
print(f"The county with the most severe accidents (Severity=4) is {most_severe_county} with {most_severe_accidents} severe accidents.")
# Out:
# The county with the most severe accidents (Severity=4) is Fulton with 458 severe accidents.
